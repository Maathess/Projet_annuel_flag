# %% [markdown]
# # <font color="orange"><center>Rattrapage Projet Annuel : Prédiction de la classe d'un drapeau</center></font>

# %% [markdown]
# ***

# %% [markdown]
# # <center>PMC : Classification</center>

# %% [markdown]
# ## 1. PMC sans couche cachée

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
mse = mpimg.imread('C:/Users/Maathess/Desktop/Projet_annuel_flag/Train_Screenshoot/0couche_mse.PNG')
acc = mpimg.imread('C:/Users/Maathess/Desktop/Projet_annuel_flag/Train_Screenshoot/0couche_acc.PNG')
hyperparam = mpimg.imread('C:/Users/Maathess/Desktop/Projet_annuel_flag/Train_Screenshoot/0couche_hyperparametre.PNG')

imgplot = plt.imshow(hyperparam)
plt.title('Hyper-paramètre')
plt.show()

imgplot = plt.imshow(mse)
plt.show()


imgplot = plt.imshow(acc)
plt.show()

# %% [raw]
# Observation : On remarque que pour le MSE il y a une convergence à partir de l'epochs 200 et 100 pour l'accuracy, et le modèle fait 17% d'erreur pour 65% de bonnes prédictions, ce qui est un bon résultat pour un premier entraînement sans couche cachée. Cela peut nous amené à l'hypothèse que pour les prochains entraînements, le modèle apprendra probablement très rapidement, ou bien nous prouver le contraire.

# %%
mse = mpimg.imread('C:/Users/Maathess/Desktop/Projet_annuel_flag/Train_Screenshoot/0couche_3train_mse.PNG')
acc = mpimg.imread('C:/Users/Maathess/Desktop/Projet_annuel_flag/Train_Screenshoot/0couche_3train_acc.PNG')
hyperparam = mpimg.imread('C:/Users/Maathess/Desktop/Projet_annuel_flag/Train_Screenshoot/0couche_3train_hyperparametre.PNG')

imgplot = plt.imshow(hyperparam)
plt.title('Hyper-paramètre')
plt.show()

imgplot = plt.imshow(mse)
plt.show()


imgplot = plt.imshow(acc)
plt.show()

# %% [raw]
# Observation : Après 3 entraînement du même modèle avec les mêmes hyper-paramètre, nous remarquons une nette amélioration  de son entraînement. Le modèle est apte à réaliser de bonne prédiction. Mais cela correspond également à une sorte de surentrainement, ce qui peut biaisé les résultats de la prédiction. Ce n'est pas une bonne méthode.

# %% [markdown]
# ***

# %% [markdown]
# ## 2. PMC avec 1 couche cachée de 8 neurones

# %%
mse = mpimg.imread('C:/Users/Maathess/Desktop/Projet_annuel_flag/Train_Screenshoot/1_8_mse.PNG')
acc = mpimg.imread('C:/Users/Maathess/Desktop/Projet_annuel_flag/Train_Screenshoot/1_8_acc.PNG')
hyperparam = mpimg.imread('C:/Users/Maathess/Desktop/Projet_annuel_flag/Train_Screenshoot/1_8_hyperparametre.PNG')

imgplot = plt.imshow(hyperparam)
plt.show()

imgplot = plt.imshow(mse)
plt.show()


imgplot = plt.imshow(acc)
plt.show()

# %% [raw]
# Observation : Le modèle s'est considérablement bien entraîner, il converge fortement autour d'un accuracy de 94%. Cepandant, cela est soit du à la résolution des images du dataset ou bien des classes d'images (couleurs) choisis.

# %%
mse = mpimg.imread('C:/Users/Maathess/Desktop/Projet_annuel_flag/Train_Screenshoot/1_8_mse2.PNG')
acc = mpimg.imread('C:/Users/Maathess/Desktop/Projet_annuel_flag/Train_Screenshoot/1_8_acc2.PNG')
hyperparam = mpimg.imread('C:/Users/Maathess/Desktop/Projet_annuel_flag/Train_Screenshoot/1_8_hyperparametre2.PNG')

imgplot = plt.imshow(hyperparam)
plt.show()

imgplot = plt.imshow(mse)
plt.show()


imgplot = plt.imshow(acc)
plt.show()

# %% [raw]
# Observation : Je me suis permis de réaliser un nouvel entraînement sur un nouveau model et cette fois-ci sur 100 epochs en plus. On voit que la courbe d'accuracy rejoins et passe même légèrement au-dessus de la courbe de validation. On a donc trouvé les bons hyper-paramètre pour ce modèle.

# %% [markdown]
# ***

# %% [markdown]
# ## 3. PMC avec 1 couche cachée de 32 neurones

# %%
mse = mpimg.imread('C:/Users/Maathess/Desktop/Projet_annuel_flag/Train_Screenshoot/1_32_mse.PNG')
acc = mpimg.imread('C:/Users/Maathess/Desktop/Projet_annuel_flag/Train_Screenshoot/1_32_acc.PNG')
hyperparam = mpimg.imread('C:/Users/Maathess/Desktop/Projet_annuel_flag/Train_Screenshoot/1_32_hyperparametre.PNG')

imgplot = plt.imshow(hyperparam)
plt.show()

imgplot = plt.imshow(mse)
plt.show()


imgplot = plt.imshow(acc)
plt.show()

# %% [raw]
# Observation : Cet entraînement nous permet de constaté que d'une part un modèle avec plus de neuronnes signifie pas forcément un meilleur entraînement pour un modèle (même si celui là est mieux que l'entraînement précédent). D'autre part, si l'on compare cet entraînement au précédent on remarque que ce modèle nécéssite peu d'epochs pour une bonne convergence et le MSE est bien meilleure.

# %% [markdown]
# ***

# %% [markdown]
# ## 3. PMC avec 2 couche cachée de 32 neurones

# %%
mse = mpimg.imread('C:/Users/Maathess/Desktop/Projet_annuel_flag/Train_Screenshoot/2_32_mse.PNG')
acc = mpimg.imread('C:/Users/Maathess/Desktop/Projet_annuel_flag/Train_Screenshoot/2_32_acc.PNG')
hyperparam = mpimg.imread('C:/Users/Maathess/Desktop/Projet_annuel_flag/Train_Screenshoot/2_32_hyperparametre.PNG')

imgplot = plt.imshow(hyperparam)
plt.show()

imgplot = plt.imshow(mse)
plt.show()


imgplot = plt.imshow(acc)
plt.show()

# %% [raw]
# Observation : Avec des hyper-paramètres similaires aux entraînements précédents, on constate que cet entraînement un début de léger cas d'overfiting. On peut en déduire que pour ce dataset, le nombre de couche cachée pour un entraînement satisfaisant ne doit pas dépasser 1 couche cachée.

# %%
mse = mpimg.imread('C:/Users/Maathess/Desktop/Projet_annuel_flag/Train_Screenshoot/low_2_32_mse.PNG')
acc = mpimg.imread('C:/Users/Maathess/Desktop/Projet_annuel_flag/Train_Screenshoot/low_2_32_acc.PNG')
hyperparam = mpimg.imread('C:/Users/Maathess/Desktop/Projet_annuel_flag/Train_Screenshoot/low_2_32_hyperparametre.PNG')

imgplot = plt.imshow(hyperparam)
plt.show()

imgplot = plt.imshow(mse)
plt.show()


imgplot = plt.imshow(acc)
plt.show()

# %% [raw]
# Observation : J'ai réalisé une nouvelle fois l'entraînement précédent mais cette fois-ci avec peu d'epochs et un pas d'apprentissage plus important. On peut remarquer que le cas d'overfiting est toujours présent, malgré un apprentissage correct pour le modèle, se dernier tend vers un sur-apprentissage.

# %% [markdown]
# ***

# %% [markdown]
# ## <font color="red"><center>CONCLUSION</center></font>

# %% [markdown]
# Pour une prédiction sûre et cohérente, l'entaînement du modèle ne doit avoir plus d'une couche cachée.
